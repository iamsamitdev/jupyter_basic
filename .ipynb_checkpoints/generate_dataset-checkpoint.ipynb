# %%
import pandas as pd
import random

# %%
names = ["Albert","John","Richard","Henry","William"]
surnames = ["Goodman","Black","White","Green","Joneson"]
salaries = [500*random.randint(10,30) for _ in range(10)]

# %%
def generate_random_person(names, surnames, salaries):
    return {"name":random.sample(names,1)[0],
            "surname":random.sample(surnames,1)[0],
            "salary":random.sample(salaries,1)[0]}
def generate_people(k):
    return [generate_random_person(names, surnames, salaries) for _ in range(k)]

# %%
generate_random_person(names, surnames, salaries)
# Out:
# {'name': 'William', 'surname': 'Joneson', 'salary': 12500}

# %%
df = pd.DataFrame(generate_people(50),columns=["name","surname","salary"])

# %%
df
# Out:
#        name  surname  salary
# 0     Henry    Green    5000
# 1    Albert  Joneson    9000
# 2   William    White    6500
# 3      John    Black   12500
# 4      John    Black   10500
# 5      John    Green    8500
# 6   William    Green    6000
# 7   Richard  Goodman   12500
# 8     Henry  Joneson    5500
# 9      John    White    8500
# 10     John    White    9000
# 11  William    White    6500
# 12     John  Goodman    6000
# 13   Albert  Goodman    8500
# 14  William    White    9000
# 15     John  Joneson    8500
# 16   Albert    Black    6500
# 17    Henry    Green   12500
# 18  William  Goodman    6500
# 19  William  Goodman    6000
# 20    Henry    Green    6500
# 21    Henry  Goodman    5500
# 22     John  Goodman   10500
# 23     John    Green    6500
# 24  William    Black   12500
# 25    Henry    Black    9000
# 26  Richard    Green   12500
# 27  Richard  Goodman    9000
# 28   Albert    Green   12500
# 29    Henry    White    6500
# 30     John  Goodman    5500
# 31    Henry    Black    9000
# 32    Henry  Goodman    8500
# 33    Henry  Joneson   12500
# 34   Albert    White   10500
# 35  Richard  Goodman    9000
# 36   Albert  Goodman    8500
# 37  Richard  Goodman    9000
# 38    Henry    Black    5000
# 39   Albert  Goodman    9000
# 40     John    White   12500
# 41    Henry  Goodman    6500
# 42   Albert    Black    5500
# 43     John    White    8500
# 44    Henry    White    5500
# 45   Albert    Black    5000
# 46  Richard  Goodman    5500
# 47    Henry  Joneson    6500
# 48  Richard  Joneson    6500
# 49  Richard    Black    5000
